# %% [markdown]
# # Carbon fiber welding hood making process
# Below is the general cost, production process, businesses for outsourcing, etc

# %% [markdown]
# ## ***Cost estimation:***
#
# #### Products for 3D print:
# - Bambu Hotend - P1 Series -                                       $14.99
# - Hardended steel extruder gear assembly -                         $19.99
# - 1Kg PA6-CF filament roll -                                       $79.99
# - SUNLU Filament Dryer S2 -                                        $44.99
# - Vision Miner Nano Polymer Adhesive (50ml) -                      $19.00
#
# #### 3D Printing total = ***$200*** accounting for shipping and taxes
#
# ----------------------------------------------------------------------------------------------------------------------------
#
# #### Prepreg Carbon Fiber Starter Kit (Regular) *** POSSIBLE ***:
# Total cost - $325.50
# Includes:
# - XPREG XC110 Prepreg Carbon 3K, 210g (6.2oz/yd), 2/2 Twill  -  1m x 1.25m  (39 x 49")
# - XPREG XC110 Prepreg Carbon 6K, 416g (12.3oz/yd), 2/2 Twill  -  1m x 1.25m  (39 x 49")
# - Unperforated Release Film  -  2m x 1.52m (79 x 60")
# - Vacuum Bagging Film LFT  -  5m x 1.52m (197 x 60")
# - Breather Cloth  -  2m x 1.52m (79 x 60")
# - Vacuum Bagging Gum Tape  -  2x 15m (16.4yd) Rolls
# - Through Bag Connector  -  1 unit
# - 1/4 Turn Valve  -  1
# - 8mm (0.31") ID Hosetail Barb Connector  -  1
# - 8mm (0.31") ID Sillicon Hose - 2m
# - Nitrile Gloves   -  10 Pairs
#
# ----------------------------------------------------------------------------------------------------------------------------
#
# #### Vacuum bagging starter kit w built in regulator + vacuum
# - about $52 vacuum
# - about 127.40 for the starter kit
# - total is $
#
# ----------------------------------------------------------------------------------------------------------------------------
#
# #### 90 square feet of prepreg carbon fiber (US verison)
# - about $375

# %% [markdown]
# ## Notes from caden 9/14/26
# - favor: call or email bambu labs asking about if the 3d print can be baked over and over at 250 degrees f for 4 hours multiple times. 4 hours is the typical curing time.
# - Research 2 piece sandwich mold. Talk to ability composites.com and see about the sandwich mold.
# - Try to get quote from Xometry about a sandwich mold.
