# %% [markdown]
# # This notebook contains the businesses we are interested in and thier function
#
# --------------------------------------------------------------------

# %% [markdown]
# ## ***Easy Composites US***
# #### Website: [easycomposites.us](https://www.easycomposites.us/)
#
# #### Function:
# - Provide vacuum bagging starter kit if needed. Provide the actual vacuum with a built in regulator. Easy Composites provides numerous videos on youtube about working with carbon fiber. This includes carbon fiber prepregs, designing molds, etc. They also can provide carbon fiber prepreg starter kits if needed. The main function is providing carbon fiber prepregs.
#
# #### Youtube Account & Video links:
# - [Easy Composites Youtube Channel](https://www.youtube.com/@easycompositestv)
# - [Mould Design & Strength Optimisation](https://www.youtube.com/watch?v=nhqAhYOdGNc)
# - [Hand Laminating a Carbon Fibre Part Directly into a 3D Printed Mould](https://www.youtube.com/watch?v=4ND2WtEZatY&list=PL-DQ6gqgQvCk7QK_4LeouNbKbf6o6n6Mn&index=2)
# - [How to Make Prepreg Carbon Fibre Parts (XPREG® XC110)](https://www.youtube.com/watch?v=HfrFaKDsJxc)
#
# --------------------------------------------------------------------

# %% [markdown]
# ## ***Bambu Labs***
#
# #### Website: [bambulab.com](https://bambulab.com/en)
#
# #### Function:
# - Provide materials and tools to 3D print test models or moulds. Provides information on 3D print materials. Mainly used for test designs to then transfer into stronger moulds. Also to show real world size and looks of welding hood designs.
#
# #### Links to test materials:
# - [PA6-CF Filament](https://us.store.bambulab.com/products/pa6-cf)
# - Cheap test print material: [PETG Basic](https://us.store.bambulab.com/products/petg-basic)
#
# --------------------------------------------------------------------

# %% [markdown]
# ## ***Xometry***
#
# #### Website: [Xometry.com](https://www.xometry.com/?msclkid=a7da11b202fd152015b37b1ab68500c6&utm_source=bing&utm_medium=cpc&utm_campaign=PB%3AM%7CNT%3ASN%7CAN%3AManufacturing%7CCN%3ABranded&utm_term=xometry&utm_content=PB%3AM%7CNT%3ASN%7CAN%3AManufacturing%7CCN%3ABranded%7CPN%3AGen)
#
# #### Function:
# - Xometry does CNC Machining, 3D Printing, Sheet & Tube Fabrication, Injection Molding, etc. We are looking into their ability to 3D print a mould for the hoods out of aluminum. This would allow us to reliably bake carbon fiber prepregs at high temps. The pricing is unknown for now until I can design a mould then get a quote from them. The cost is likely going to be expensive.
#
# --------------------------------------------------------------------

# %% [markdown]
# ## ***Ability Composites***
#
# #### Website: [abilitycomposites.com](https://abilitycomposites.com/)
#
# #### Function:
# - Ability Composites is based in Loveland, Colorado and provides 5 main services. Each service title acts as an umbrella to fit many different customer needs. The services are Composite Layup, Composite Engineering, Filament Winding, Composite Tooling & Molds, and Autoclave & Ovens. We are mainly interested in two of the services. Composite engineering can offer advice on materials that we use for the molds or for the hoods themselves. The other service is their Composite Tooling & Molds. We could use them to make durable and reliable molds for hood mass production.
#
# --------------------------------------------------------------------
